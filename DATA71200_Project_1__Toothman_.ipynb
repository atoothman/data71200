# %% [markdown]
# <a href="https://colab.research.google.com/github/atoothman/data71200/blob/main/DATA71200_Project_1__Toothman_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DATA 71200 - Project 1
#
# The Abalone dataset used was found on the UC Irvine Machine Learning Repository.
#
# [https://archive.ics.uci.edu/dataset/1/abalone](https://)
#
#
# Features of this data set include sex, length, diameter, height, whole weight, shucked weight, viscera weight and shell weight.
#
# The target (dependent variable) is the number of rings found in the abalone shell. The amount of rings in a shell denotes the age of the abalone.

# %% [markdown]
# # Step 1: Find and download the dataset

# %%
#Step 1: import the abalone dataset from UC Irvine Repository
import pandas as pd
# !pip3 install -U ucimlrepo

from ucimlrepo import fetch_ucirepo

# fetch dataset
abalone = fetch_ucirepo(id=1)

# data (as pandas dataframes)
X = abalone.data.features
y = abalone.data.targets

# metadata
print(abalone.metadata)

# variable information
print(abalone.variables)

#examine data
#print(X, y)
# Out:
# ERROR: Operation cancelled by user
# ...

# %%
import pandas as pd

# URL of the Abalone dataset on the UCI Machine Learning Repository
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/abalone/abalone.data"

# Define column names
columns = ['Sex', 'Length', 'Diameter', 'Height', 'Whole weight',
           'Shucked weight', 'Viscera weight', 'Shell weight', 'Rings']

# Read the dataset into a pandas DataFrame
abalone_df = pd.read_csv(url, header=None, names=columns)

# Display the DataFrame
display(abalone_df)
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
#one-hot-encoding step to translate Sex

# %% [markdown]
# # Step 2: Divide into a training set and testing set

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-91ddbb78d75c> in <cell line: 4>()
#       2
#       3 # instantiate a model and fit it to the training set
# ----> 4 linreg = LinearRegression().fit(X_train, y_train)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     646         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     647
# --> 648         X, y = self._validate_data(
#     649             X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     650         )
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     582                 y = check_array(y, input_name="y", **check_y_params)
#     583             else:
# ...
